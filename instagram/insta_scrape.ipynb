# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup
import pandas as pd
import urllib
import requests
import re
import random
from database_insta import *

# %%
class Insta:
    def __init__(self,username,password):
        self.username = username
        self.password = password
        #self.bot = webdriver.Firefox()
        chrome_options = Options()
        #chrome_options.add_argument("--headless")
        #chrome_options.add_argument("--no-sandbox")

        #chrome_options.add_argument("--disable-gpu")
        self.bot = webdriver.Chrome('chromedriver',options=chrome_options)
        self.bot.get('https://www.instagram.com/akshaykumar/')
    
    def login(self):
        bot = self.bot
        bot.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
        time.sleep(3)
        email = bot.find_element_by_name('username')
        password = bot.find_element_by_name('password')
        email.clear()
        password.clear()
        email.send_keys(self.username)
        password.send_keys(self.password)
        password.send_keys(Keys.RETURN)
        time.sleep(5)
        try:
            notif_dialog = bot.find_element_by_class_name('aOOlW.HoLwm').click()
        except:
            print("dialog not found")
        print("login complete")
    
    def posts(self,hashtag):
        print("def posts start")
        bot = self.bot
        bot.get('https://www.instagram.com/explore/tags/{}/'.format(hashtag))
        time.sleep(2)
        post_links = []
        for i in range(0,10):
            bot.execute_script('window.scrollTo(0,document.body.scrollHeight)')
            time.sleep(2)
            posts = bot.find_elements_by_class_name('v1Nh3.kIKUG._bz0w')
            for post in posts:
                post_links.append(post.find_element_by_css_selector('a').get_attribute('href'))
                print(len(post_links))
        print("post_links len",len(post_links))
        post_links = list(set(post_links))
        print("set post_links",len(post_links))
        f = open('post_links.txt','w')
        for i in post_links:
            f.write(i+'\n')
        f.close()
        #print("post_links len",len(post_links))
        print("def posts end")
    
    def profiles(self):
        bot = self.bot
        print("def profiles start")
        post_links = []
        f = open('post_links.txt','r')
        for i in f:
            post_links.append(i.rstrip())
        f.close()
        profiles =[]
        for i in post_links:
            bot.get(i)
            time.sleep(3)
            try:
                profile = bot.find_element_by_class_name('sqdOP.yWX7d._8A5w5.ZIAjV').get_attribute('href')
                profiles.append(profile)
                print(len(profiles))
            except Exception as e:
                print(e)
        profiles = list(set(profiles))
        print(len(profiles))
        f = open('profiles.txt','w')
        for i in profiles:
            f.write(i+'\n')
        f.close()
        print("def profiles end")
    
    def scraping_profiles(self):
        bot = self.bot
        print('def scraping_profiles start')
        profiles =[]
        f = open('profiles.txt','r')
        for i in f:
            profiles.append(i.rstrip())
        f.close()
        insta_links =[]
        names =[]
        websites =[]
        emails =[]
        for profile in profiles:
            bot.get(profile)
            time.sleep(3)
            try:
                name = bot.find_element_by_class_name('rhpdm').text
                website = bot.find_element_by_class_name('yLUwa').get_attribute('href')
                x = website.find('=')
                y = website.find('&e')
                website = urllib.parse.unquote(website[x+1:y])
                
            except Exception as e:
                print(e)
                #time.sleep(120)
                
                name =''
                website =''
            print(name,website)
            
            insta_links.append(i)
            names.append(name)
            websites.append(website)
            print(len(insta_links),len(names),len(websites))
        
        for i in websites:
            try:
                response = requests.get(i)
                soup = BeautifulSoup(response.text,'html.parser')
                all_text = soup.find('body').getText()
                #print(all_text,type(all_text))
                web_email = list(set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z0-9\.\-+_]+", all_text, re.I)))
                '''
                if len(web_email)>0:
                    emails.append(web_email[0])
                    print(web_email[0],len(emails))
                else:
                    emails.append('')
                    print("Didnt find",len(emails))
                time.sleep(1)
            except:
                emails.append('')
                print("error",len(emails))
                '''
                if len(web_email) > 0:
                    temp = ''
                    for j in web_email:
                        try:
                            if validate_email(j):
                                emails.append(j)
                                temp = j
                                print(j,len(emails))
                                break
                        except:
                            continue
                    if temp == '':
                        emails.append('')
                        print("Didnt find",len(emails))
                else:
                    emails.append('')
                    print("Didnt find",len(emails))
        
        df = pd.DataFrame({'Business_Name':names,
                          'Instagram_Link':insta_links,
                          'Website':websites,
                          'Email':emails})
        df.to_csv('unfiltered.csv',index=False)
            
        print('def scraping_profiles end')
        return insta_links,names,websites,emails
# Out:
#   File "<ipython-input-37-fb4496785a0d>", line 153
#     df = pd.DataFrame({'Business_Name':names,
#     ^
# IndentationError: unexpected unindent

# %%
keyword = 'dentist'
s = Insta('_fifty_shades_of_us_','Aryman@235')
#s.login()
#s.posts(keyword)
#s.profiles()
insta_links,names,websites,emails = s.scraping_profiles()
# Out:
# def scraping_profiles start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 1 1 1
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 2 2 2
# Centre Dentaire SMILE WELL http://www.smilewell.ma/
# 3 3 3
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 4 4 4
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 5 5 5
# Indo Dental Center https://www.jd.id/product/indo-dental-center-whitening_611397767/611397768.html
# 6 6 6
# طبيب اسنان وزراعة و تجميل وجه https://karti.me/u/dr-yazan-smadi
# 7 7 7
# Ｒｅｂｅｃｃａ | Ｄｅｎｔａｌ Ｎｕｒｓｅ http://dentalnursepower.blogspot.com/
# 8 8 8
# Hell-Bent® Holsters http://www.hellbentholsters.com/
# 9 9 9
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 10 10 10
# Ontario Dental Implant Network http://livedentalsurgery.com/
# 11 11 11
# Clinica Zâmbet Fericit https://www.zambetfericit.ro/
# 12 12 12
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 13 13 13
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 14 14 14
# The Professional Plug http://www.theprofessionalplug.com/
# 15 15 15
# Photography Is Medicine https://www.meetup.com/Photography-Is-Medicine/
# 16 16 16
# Gentle Dental & Implant Clinic http://www.gentledentalclinic.com/
# 17 17 17
# ARNAOUTIS LASER DENTISTRY http://www.arnaoutisdental.com/
# 18 18 18
# Ascent Dental Solutions https://www.ascent-dental-solutions.com/speaking-programs/principles-for-success/
# 19 19 19
# Savannah Dental http://www.savannah.dental/
# 20 20 20
# Kulzer Iberia http://www.linktr.ee/kulzeriberia
# 21 21 21
# Absolute Aesthetics Clinic https://dentalhouseliverpool.co.uk/virtual-consultation/
# 22 22 22
# Clinica Doc. Belen Lacarte. https://www.clinicadentalbelenlacarte.com/
# 23 23 23
# Wilmington Orthodontic Center https://www.orthodontistwilmington.com/
# 24 24 24
# 南館歯科クリニック https://linktr.ee/minamidate
# 25 25 25
# Consultório Rossi Odontologia http://api.whatsapp.com/send?1=pt_BR&phone=5535998557186
# 26 26 26
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 27 27 27
# Southwest Endodontics http://www.southwestendo.com/
# 28 28 28
# The Smile Clinic 🦷 https://www.thesmileclinic.uk.com/
# 29 29 29
# Greenfield Dental Care http://www.greenfielddentalcare.com/
# 30 30 30
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 31 31 31
# AdDent, Inc http://www.addent.com/
# 32 32 32
# Praxisfuerzahngesundheit https://www.zahngesundheit-neustadt.de/
# 33 33 33
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 34 34 34
# Matteo__Negri http://matteonegri.it/
# 35 35 35
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 36 36 36
# Hdental Store http://www.hdentalstore.ro/
# 37 37 37
# PARIMI’S DENTAL CARE http://parimidentalcare.com/
# 38 38 38
# 3M Ortho https://www.excellere3m.com/
# 39 39 39
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 40 40 40
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
#
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 92 92 92
# Love St Andrews http://www.facebook.com/StAndrewsFife/
# 93 93 93
# 𝗖𝗲𝗻𝘁𝗿𝗼 𝗱𝗲 𝗣𝗿𝗼́𝘁𝗲𝘀𝗶𝘀 𝗗𝗲𝗻𝘁𝗮𝗹 http://www.centrodeprotesisdentales.com/
# 94 94 94
# Ortodontist Gizem Akgün Karslı https://cutt.ly/uzmdtgizemakgunkarsli
# 95 95 95
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 96 96 96
# Dr. Andi-Jean Miro http://aparosenthal.com/
# 97 97 97
# GC Poland http://l.ead.me/bb5peV/
# 98 98 98
# Brand Manager http://ventesmile.com/
# 99 99 99
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 100 100 100
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 101 101 101
# Smiles Unlimited https://smilesunlimited.com.au/receding-gums/
# 102 102 102
# Studio kids Puebla https://m.facebook.com/StudioKidsPuebla/
# 103 103 103
# Dr KAMA BDS PGDip MJDF RCS Eng https://www.kensingtoncosmeticdentist.co.uk/
# 104 104 104
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 105 105 105
# أبولونيا المتقدم|أسنان الأطفال http://wa.me/971588295100
# 106 106 106
# TWO https://youtu.be/28nHlvTRDTc
# 107 107 107
# drmaryamvalipour https://t.me/maryam_valipour
# 108 108 108
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 109 109 109
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 110 110 110
# Dr. Athina Tsiorva DDS https://dental-lifestyle.com/el/leukansi-erwtiseis-apantiseis/
# 111 111 111
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 112 112 112
# ᴅʀ. ɪsᴀᴀᴋ ʏᴇʟɪᴢᴀʀ⏐ᴏʀᴛʜᴏᴅᴏɴᴛɪsᴛ http://www.simplibraces.com/
# 113 113 113
# Orthodontic Mentor Pro https://identalshop.com/suturing-kits
# 114 114 114
# Maryara Gasquez | Dentista https://whats.link/maryaragasquez
# 115 115 115
# Gou Odonto Lucélia https://wa.me/message/TBPS7XLFNANDB1
# 116 116 116
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 117 117 117
# Allen House Dental Practice http://www.allenhousedental.co.uk/
# 118 118 118
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 119 119 119
# Koloszár Enikő https://youtu.be/Ud01AjKl2bo
# 120 120 120
# error 1
# error 2
# cdsmilewell@gmail.com 3
# error 4
# error 5
# Didnt find 6
# Didnt find 7
# Didnt find 8
# Didnt find 9
# error 10
# info@livedentalsurgery.com 11
# Didnt find 12
# error 13
# error 14
# connect@theprofessionalplug.comCopyright 15
# Didnt find 16
# info@gentledentalclinic.com 17
# Didnt find 18
# error 19
# Didnt find 20
# Didnt find 21
# chloe.hale@dentalhouseliverpool.co.uk 22
# arteestallo@gmail.com 23
# info@orthodontistwilmington.com 24
# Didnt find 25
# Didnt find 26
# error 27
# error 28
# enquiries@thesmileclinic.uk.com 29
# UKsurgery@greenfielddentalcare.com029 30
# error 31
# info@addent.com 32
# Didnt find 33
# error 34
# Didnt find 35
# error 36
# info@hdentalstore.ro.vc_custom_1492520298430 37
# Didnt find 38
# Didnt find 39
# error 40
# error 41
# Didnt find 42
# Dentalexcellencepc@hotmail.comRequest 43
# Didnt find 44
# error 45
# Didnt find 46
# error 47
# Didnt find 48
# Didnt find 49
# Didnt find 50
# Didnt find 51
# Didnt find 52
# Didnt find 53
# Didnt find 54
# Didnt find 55
# wixofday@wix.com 56
# info@thedentistputney.com 57
# error 58
# Didnt find 59
# Didnt find 60
# error 61
# Didnt find 62
# Didnt find 63
# error 64
# Didnt find 65
# error 66
# info@oskin.in 67
# Didnt find 68
# Didnt find 69
# Didnt find 70
# error 71
# info@sonatacare.com.au 72
# Didnt find 73
# error 74
# Didnt find 75
# error 76
# Didnt find 77
# Didnt find 78
# Didnt find 79
# Didnt find 80
# Didnt find 81
# Didnt find 82
# error 83
# error 84
# Didnt find 85
# error 86
# Didnt find 87
# error 88
# Didnt find 89
# error 90
# Didnt find 91
# error 92
# Didnt find 93
# Didnt find 94
# error 95
# error 96
# Didnt find 97
# Didnt find 98
# Didnt find 99
# error 100
# error 101
# admin@smilesunlimited.com.au 102
# error 103
# error 104
# error 105
# Didnt find 106
# Didnt find 107
# Didnt find 108
# error 109
# error 110
# Didnt find 111
# error 112
# Didnt find 113
# Didnt find 114
# Didnt find 115
# Didnt find 116
# error 117
# info@allenhousedental.co.uk 118
# error 119
# koloszar.eniko@gmail.com 120
# def scraping_profiles end

# %%
df = pd.read_csv('unfiltered.csv')
df.shape
# Out:
# (120, 4)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (19, 4)

# %%
df.to_csv('filtered.csv',index=False)

# %%
db()
# Out:
# Centre Dentaire SMILE WELL https://www.instagram.com/enikokoloszar/
#  http://www.smilewell.ma/ cdsmilewell@gmail.com
# Ontario Dental Implant Network https://www.instagram.com/enikokoloszar/
#  http://livedentalsurgery.com/ info@livedentalsurgery.com
# The Professional Plug https://www.instagram.com/enikokoloszar/
#  http://www.theprofessionalplug.com/ connect@theprofessionalplug.comCopyright
# Gentle Dental & Implant Clinic https://www.instagram.com/enikokoloszar/
#  http://www.gentledentalclinic.com/ info@gentledentalclinic.com
# Absolute Aesthetics Clinic https://www.instagram.com/enikokoloszar/
#  https://dentalhouseliverpool.co.uk/virtual-consultation/ chloe.hale@dentalhouseliverpool.co.uk
# Clinica Doc. Belen Lacarte. https://www.instagram.com/enikokoloszar/
#  https://www.clinicadentalbelenlacarte.com/ arteestallo@gmail.com
# Wilmington Orthodontic Center https://www.instagram.com/enikokoloszar/
#  https://www.orthodontistwilmington.com/ info@orthodontistwilmington.com
# The Smile Clinic 🦷 https://www.instagram.com/enikokoloszar/
#  https://www.thesmileclinic.uk.com/ enquiries@thesmileclinic.uk.com
# Greenfield Dental Care https://www.instagram.com/enikokoloszar/
#  http://www.greenfielddentalcare.com/ UKsurgery@greenfielddentalcare.com029
# AdDent, Inc https://www.instagram.com/enikokoloszar/
#  http://www.addent.com/ info@addent.com
# Hdental Store https://www.instagram.com/enikokoloszar/
#  http://www.hdentalstore.ro/ info@hdentalstore.ro.vc_custom_1492520298430
# Dental Excellence PC Memphis https://www.instagram.com/enikokoloszar/
#  http://dentalexcellencepc.com/ Dentalexcellencepc@hotmail.comRequest
# МЕДЦЕНТР ЭМИЛИЯ КЕМЕРОВО https://www.instagram.com/enikokoloszar/
#  http://mc-emilia.com/ wixofday@wix.com
# The Dentist https://www.instagram.com/enikokoloszar/
#  http://www.thedentistputney.com/ info@thedentistputney.com
# oskinclinic https://www.instagram.com/enikokoloszar/
#  http://www.oskin.in/ info@oskin.in
# SonataCare https://www.instagram.com/enikokoloszar/
#  http://www.sonatacare.com.au/ info@sonatacare.com.au
# Smiles Unlimited https://www.instagram.com/enikokoloszar/
#  https://smilesunlimited.com.au/receding-gums/ admin@smilesunlimited.com.au
# Allen House Dental Practice https://www.instagram.com/enikokoloszar/
#  http://www.allenhousedental.co.uk/ info@allenhousedental.co.uk
# Koloszár Enikő https://www.instagram.com/enikokoloszar/
#  https://youtu.be/Ud01AjKl2bo koloszar.eniko@gmail.com
