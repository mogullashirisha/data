# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup
import pandas as pd
import urllib
import requests
import re
import random
from database_insta import *

# %%
class Insta:
    def __init__(self,username,password):
        self.username = username
        self.password = password
        #PROXY = '103.250.157.34:44611'
        #self.bot = webdriver.Firefox()
        chrome_options = Options()
        #chrome_options.add_argument("--headless")
        #chrome_options.add_argument("--no-sandbox")
        #chrome_options.add_argument('--proxy-server=%s' % PROXY)
        #chrome_options.add_argument("--disable-gpu")
        self.bot = webdriver.Chrome('chromedriver',options=chrome_options)
        self.bot.get('https://www.instagram.com/akshaykumar/')
    
    def login(self):
        bot = self.bot
        bot.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
        time.sleep(3)
        email = bot.find_element_by_name('username')
        password = bot.find_element_by_name('password')
        email.clear()
        password.clear()
        email.send_keys(self.username)
        password.send_keys(self.password)
        password.send_keys(Keys.RETURN)
        time.sleep(5)
        try:
            notif_dialog = bot.find_element_by_class_name('aOOlW.HoLwm').click()
        except:
            print("dialog not found")
        print("login complete")
    
    def posts(self,hashtag):
        print("def posts start")
        bot = self.bot
        bot.get('https://www.instagram.com/explore/tags/{}/'.format(hashtag))
        time.sleep(2)
        post_links = []
        for i in range(0,10):
            bot.execute_script('window.scrollTo(0,document.body.scrollHeight)')
            time.sleep(2)
            posts = bot.find_elements_by_class_name('v1Nh3.kIKUG._bz0w')
            for post in posts:
                post_links.append(post.find_element_by_css_selector('a').get_attribute('href'))
                print(len(post_links))
        print("post_links len",len(post_links))
        post_links = list(set(post_links))
        print("set post_links",len(post_links))
        f = open('post_links.txt','w')
        for i in post_links:
            f.write(i+'\n')
        f.close()
        #print("post_links len",len(post_links))
        print("def posts end")
    
    def profiles(self):
        bot = self.bot
        print("def profiles start")
        post_links = []
        f = open('post_links.txt','r')
        for i in f:
            post_links.append(i.rstrip())
        f.close()
        profiles =[]
        for i in post_links:
            bot.get(i)
            time.sleep(3)
            try:
                profile = bot.find_element_by_class_name('sqdOP.yWX7d._8A5w5.ZIAjV').get_attribute('href')
                profiles.append(profile)
                print(len(profiles))
            except Exception as e:
                print(e)
        profiles = list(set(profiles))
        print(len(profiles))
        f = open('profiles.txt','w')
        for i in profiles:
            f.write(i+'\n')
        f.close()
        print("def profiles end")
    
    def scraping_profiles(self):
        bot = self.bot
        print('def scraping_profiles start')
        profiles =[]
        f = open('profiles.txt','r')
        for i in f:
            profiles.append(i.rstrip())
        f.close()
        insta_links =[]
        names =[]
        websites =[]
        emails =[]
        for profile in profiles:
            bot.get(profile)
            time.sleep(3)
            try:
                name = bot.find_element_by_class_name('rhpdm').text
                website = bot.find_element_by_class_name('yLUwa').get_attribute('href')
                x = website.find('=')
                y = website.find('&e')
                website = urllib.parse.unquote(website[x+1:y])
                
            except Exception as e:
                print(e)
                #time.sleep(120)
                
                name =''
                website =''
            print(name,website)
            
            insta_links.append(i)
            names.append(name)
            websites.append(website)
            print(len(insta_links),len(names),len(websites))
        
        for i in websites:
            try:
                response = requests.get(i)
                soup = BeautifulSoup(response.text,'html.parser')
                all_text = soup.find('body').getText()
                #print(all_text,type(all_text))
                web_email = list(set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z0-9\.\-+_]+", all_text, re.I)))
                
                if len(web_email)>0:
                    emails.append(web_email[0])
                    print(web_email[0],len(emails))
                else:
                    emails.append('')
                    print("Didnt find",len(emails))
                time.sleep(1)
            except:
                emails.append('')
                print("error",len(emails))
                '''
                if len(web_email) > 0:
                    temp = ''
                    for j in web_email:
                        try:
                            if validate_email(j):
                                emails.append(j)
                                temp = j
                                print(j,len(emails))
                                break
                        except:
                            continue
                    if temp == '':
                        emails.append('')
                        print("Didnt find",len(emails))
                else:
                    emails.append('')
                    print("Didnt find",len(emails))
                '''
        df = pd.DataFrame({'Business_Name':names,
                          'Instagram_Link':insta_links,
                          'Website':websites,
                          'Email':emails})
        df.to_csv('unfiltered.csv',index=False)
            
        print('def scraping_profiles end')
        return insta_links,names,websites,emails

# %%
keyword = 'dentist'
s = Insta('_fifty_shades_of_us_','Aryman@235')
s.login()
#s.posts(keyword)
#s.profiles()
insta_links,names,websites,emails = s.scraping_profiles()
# Out:
# login complete
# def scraping_profiles start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 1 1 1
# Veronika Gjata http://www.kissdent.com/
# 2 2 2
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 3 3 3
# 𝚃𝚑𝚘𝚞𝚜𝚊𝚗𝚍𝚜 𝙷𝚎𝚕𝚙𝚎𝚍 & 𝙷𝚒𝚛𝚎𝚍! https://linktr.ee/thesourcela
# 4 4 4
# Patriot Family Dental http://www.patriotfamilydentalep.com/
# 5 5 5
# 𝑵𝒊𝒍𝒐𝒐𝒇𝒂𝒓 𝑺𝒂𝒇𝒂𝒓𝒊𝒓𝒂𝒅 http://t.me/nilgraph
# 6 6 6
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 7 7 7
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 8 8 8
# Bia Flores | Cirurgiã-Dentista https://api.whatsapp.com/send?phone=5511991805132
# 9 9 9
# Middletown Pediatric Dental http://www.middletownpediatricdental.com/
# 10 10 10
# Dr. Alex Guilger http://www.vueodonto.com/
# 11 11 11
# Hot Pulp Podcast https://launchlinks.io/u/dentistsofinsta
# 12 12 12
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 13 13 13
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 14 14 14
# Ehab Moussa, DDS, MSD https://cidn-edu.com/p/soft-tissue/?affcode=535538_3jyi6qkd
# 15 15 15
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 16 16 16
# dr Milos Ljubicic http://www.milosljubicic.com/
# 17 17 17
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 18 18 18
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 19 19 19
# ARM & HAMMER™ Oral Care Pro https://buff.ly/3bB6YWK
# 20 20 20
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 21 21 21
# Dra. Fátima Arévalo Sandoval https://wa.me/message/25NF3XWJSRYMM1
# 22 22 22
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 23 23 23
# Minnesota Orthodontics Rogers http://www.minnesotaorthodontics.com/
# 24 24 24
# ProDentist http://www.prodentist.com.pl/
# 25 25 25
# Dr. Yusif http://www.ayclinics.com/
# 26 26 26
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 27 27 27
# White Smile Dental Clinic https://www.facebook.com/White-Smile-114048533664758/
# 28 28 28
# Dra. Nazarith Zambrano https://bit.ly/2KME2jS
# 29 29 29
# Dr. James J. McCall, DDS, PA http://jamesjmccall.com/
# 30 30 30
# Smile with Cait RDH http://smilewithcait.co.za/
# 31 31 31
# Health Channel http://allhealthtv.com/ask-hanna//
# 32 32 32
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 33 33 33
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 34 34 34
# Urban Zoe Store https://urban-zoe.com/
# 35 35 35
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 36 36 36
# ProphyDent Co https://wa.me/573204628644
# 37 37 37
# Napa Valley Orthodontics http://www.napabraces.com/
# 38 38 38
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 39 39 39
# Dentistry Reinvented. https://www.tongues.club/collections/current-line-up/products/toothpaste-tablets
# 40 40 40
# Dr Hansen Liang, DDS https://app.smilevirtual.com/Dr-Hansen-Liang/sign-up
# 41 41 41
# Зубной Техник 👨‍🔧 Москва https://m.facebook.com/dima.gladkih.i?ref=bookmarks
# 42 42 42
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 43 43 43
# Prodent Search https://prodentsearch.com/
# 44 44 44
# Dental Health Spa https://dentalhealthspa.com/
# 45 45 45
# Startclass Cursos https://bit.ly/2ZWBRQ2
# 46 46 46
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 47 47 47
# DR.KERIMBEKOV👨🏻‍⚕️ https://t.me/drkerimbekov1603
# 48 48 48
# B&K • smileharmonisation http://www.benkoknehtl.si/
# 49 49 49
# DR.Baali Ayman https://goo.gl/maps/DbpfDcj9M7mmgNJK6
# 50 50 50
# Katherine Lyashenko https://f3.cool/elshnk/?hl=ru
# 51 51 51
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 52 52 52
# AR | ORTHODONTICS http://dra-adriana-rojas-ramirez96.webnode.do//
# 53 53 53
# Midwest Implant Institute https://midwestimplantinstitute.com/pages/surgical-courses-events
# 54 54 54
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 55 55 55
# Mint Dental http://mintdentalmiami.com/
# 56 56 56
# Dr.Yasir Alazzawi https://www.dryasseralazawei.com/
# 57 57 57
# دندانپزشکی دکتر روشن طلب http://www.dr-roshantalab.com/
# 58 58 58
# Dr Morag MacLarty BDS, MBChB https://www.facebook.com/rejuvenationfacialaesthetics/
# 59 59 59
# Ridgewood Dental https://linktr.ee/ridgewooddentalnwi
# 60 60 60
# Ruby Riascos | ODONTÓLOGA http://www.librometropolitanodecirugaoral.com/
# 61 61 61
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 62 62 62
# Royal Dentistry http://www.ddsdearborn.com/
# 63 63 63
# West Mill Smiles http://westmillsmiles.com/
# 64 64 64
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 65 65 65
# Dental Nachos https://www.dentalmarketingdoneright.com/nachos
# 66 66 66
# دندانپزشکى دكتر زمانى http://drlalehzamani.com/
# 67 67 67
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 68 68 68
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".rhpdm"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 69 69 69
# Dr.Rabia Merve Celik https://youtu.be/SRp4YJhhXz4
# 70 70 70
# Refine Dentistry http://www.refinedentistry.com/
# 71 71 71
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 72 72 72
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 73 73 73
# Laura M. Correa J. https://bit.ly/2kDDEZr
# 74 74 74
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 75 75 75
# Oga Dentist https://ogadentist.com/schedule
# 76 76 76
# Renato Ferreira http://www.clinicaorthos.com.br/
# 77 77 77
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 78 78 78
# O'DENT Clinica Dental http://www.odentclinicadental.com/
# 79 79 79
# СТОМАТОЛОГ Dr. Rihlits’ka http://instagram.com/ridentstom
# 80 80 80
# Dermo & Dento | دێرمۆ & دێنتۆ https://maps.apple.com/?address=213-1%2C+Iraq&auid=16305766326925802264&ll=35.569596%2C45.442638&lsp=9902&q=Dermo+&_ext=ChoKBQgEEI4BCgQIBRADCgUIBhCLAQoECAoQABIkKZgvL8A+S0FAMSGY%2FoBiSUZAOZBgT+BCRUJAQdIxjGCILEdA&t=m
# 81 81 81
# Allegro Grupo Dental https://bit.ly/2Jt6837
# 82 82 82
# Tania | Dental Student https://youtu.be/cyr-uqFPlig
# 83 83 83
# Dr. Victor & Judith Lubin 😁 https://providerbio.invisalign.com/sv/515199
# 84 84 84
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 85 85 85
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 86 86 86
# Williston Family Dental http://willistonfamilydental.com/
# 87 87 87
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 88 88 88
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 89 89 89
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 90 90 90
# Alderley Edge Dental Practice http://www.alderleyedgedental.co.uk/
# 91 91 91
# Lakhani’s Dental Laboratory https://www.facebook.com/Lakhanis-Dental-Laboratory-111760970300821/
# 92 92 92
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 93 93 93
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 94 94 94
# El Dentalista http://www.eldentalista.com/
# 95 95 95
# Oral Esthetic https://bit.ly/2wUmrkJ
# 96 96 96
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 97 97 97
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 98 98 98
# Dr. Souki 🇪🇸🇻🇪🇱🇧 http://www.clinicasouki.com/
# 99 99 99
# DentaVita http://dentavita.com.tr/
# 100 100 100
# Dr. Hansen Liang https://app.smilevirtual.com/Dr-Hansen-Liang/sign-up
# 101 101 101
# RV Pediatric Dentistry http://www.rvpediatricdentistry.com/
# 102 102 102
# توليب الطبية http://www.instagram.com/tulipmedical
# 103 103 103
# Montrose Advanced Dentistry http://www.montroseadvanceddentistry.com/
# 104 104 104
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 105 105 105
# Francesca Romana Dimaggio http://studiodentisticooralkids.com/
# 106 106 106
# RISSAY.COSMETIQUES https://t.me/joinchat/AAAAAFX7OWUaHoJjS-vPIg
# 107 107 107
# Dr. Ali Fares Al-Asady https://www.facebook.com/ali.f.alasady
# 108 108 108
# Vivian Peretto https://bit.ly/36UBEhr
# 109 109 109
# May Perpétuo https://api.whatsapp.com/send?phone=5538998715775&text=Ol%C3%A1+tudo+bem%3F+Vi+seu+instagram+e+gostaria+de+saber+mais+sobre+seu+trabalho
# 110 110 110
# Valencia Dental Center http://www.valenciadentalcenter.com/
# 111 111 111
# 지혜 https://linktr.ee/jihea
# 112 112 112
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 113 113 113
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 114 114 114
# Zyris https://linktr.ee/Zyris_Dental
# 115 115 115
# Sammi-Peony Dovey RDT RDH RDN http://www.sammipeony.co.uk/
# 116 116 116
# Majestic Dentist http://www.ddslivonia.com/
# 117 117 117
# Dr. Francisco Montamarta DDS http://DrM.center/
# 118 118 118
# 🇩 🇪 🇳 🇹 🇦 🇱 🇲 🇪 🇳 🇪 🇳 🇩 🇪 🇿 https://www.google.com/maps/place/Clinica+Dental+MENENDEZ/@40.5448459,-3.6279036,15z/data=!4m5!3m4!1s0x0:0x42b8bcc3cb128852!8m2!3d40.5448459!4d-3.6279036
# 119 119 119
# Dr. Paul Goodman https://www.dentalmarketingdoneright.com/nachos
# 120 120 120
# Will O. Deliz DMD http://delizdental.studio/
# 121 121 121
# Spazio Oral by Dr. Pontons http://api.whatsapp.com/send?phone=51979332994
# 122 122 122
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 123 123 123
# Dental Creations LTD https://dentalcreationsltd.com/free-sample-request/
# 124 124 124
# DR AREEB ANWAR BDS 🇬🇧 https://linktr.ee/drareebanwar
# 125 125 125
# Consys Group Inc. https://bit.ly/2Z4uLcy
# 126 126 126
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".yLUwa"}
#   (Session info: chrome=85.0.4183.83)
#
#
# 127 127 127
# error 1
# info@kissdent.info 2
# error 3
# Didnt find 4
# Didnt find 5
# Didnt find 6
# error 7
# error 8
# Didnt find 9
# admin@middletownpediatricdental.com 10
# error 11
# Didnt find 12
# error 13
# error 14
# Didnt find 15
# error 16
# Didnt find 17
# error 18
# error 19
# Didnt find 20
# error 21
# Didnt find 22
# error 23
# Didnt find 24
# Didnt find 25
# Didnt find 26
# error 27
# Didnt find 28
# Didnt find 29
# Didnt find 30
# Didnt find 31
# Didnt find 32
# error 33
# error 34
# Didnt find 35
# error 36
# Didnt find 37
# hello@napabraces.com 38
# error 39
# Didnt find 40
# hello@smilevirtual.com 41
# Didnt find 42
# error 43
# Didnt find 44
# admin@dentalhealthspa.co.uk. 45
# Didnt find 46
# error 47
# Didnt find 48
# info@benkoknehtl.si 49
# Didnt find 50
# Didnt find 51
# error 52
# 4773390534@dra.adrianarojasr 53
# Didnt find 54
# error 55
# Didnt find 56
# error 57
# info@dr-roshantalab.com 58
# Didnt find 59
# Didnt find 60
# Didnt find 61
# error 62
# Didnt find 63
# Didnt find 64
# error 65
# Didnt find 66
# Didnt find 67
# error 68
# error 69
# Didnt find 70
# contact@refinedentistry.com 71
# error 72
# error 73
# Didnt find 74
# error 75
# Didnt find 76
# Didnt find 77
# error 78
# wixofday@wix.com 79
# Didnt find 80
# Didnt find 81
# Didnt find 82
# Didnt find 83
# Didnt find 84
# error 85
# error 86
# Didnt find 87
# error 88
# error 89
# error 90
# Didnt find 91
# Didnt find 92
# error 93
# error 94
# pacientesMorethedentalist.odontologia@gmail.com9435378 95
# Didnt find 96
# error 97
# error 98
# Didnt find 99
# Didnt find 100
# hello@smilevirtual.com 101
# Didnt find 102
# Didnt find 103
# Didnt find 104
# error 105
# Didnt find 106
# Didnt find 107
# Didnt find 108
# Didnt find 109
# Didnt find 110
# 643-6424Emailhello@valenciadentalcenter.com 111
# Didnt find 112
# error 113
# error 114
# Didnt find 115
# Didnt find 116
# Didnt find 117
# Didnt find 118
# Didnt find 119
# Didnt find 120
# Didnt find 121
# Didnt find 122
# error 123
# Didnt find 124
# Didnt find 125
# Didnt find 126
# error 127
# def scraping_profiles end

# %%
df = pd.read_csv('unfiltered.csv')
df.shape
# Out:
# (127, 4)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (13, 4)

# %%
df.to_csv('filtered.csv',index=False)

# %%
db()
# Out:
# Veronika Gjata https://www.instagram.com/perio.colmex/
#  http://www.kissdent.com/ info@kissdent.info
# Middletown Pediatric Dental https://www.instagram.com/perio.colmex/
#  http://www.middletownpediatricdental.com/ admin@middletownpediatricdental.com
# Napa Valley Orthodontics https://www.instagram.com/perio.colmex/
#  http://www.napabraces.com/ hello@napabraces.com
# Dr Hansen Liang, DDS https://www.instagram.com/perio.colmex/
#  https://app.smilevirtual.com/Dr-Hansen-Liang/sign-up hello@smilevirtual.com
# Dental Health Spa https://www.instagram.com/perio.colmex/
#  https://dentalhealthspa.com/ admin@dentalhealthspa.co.uk.
# B&K • smileharmonisation https://www.instagram.com/perio.colmex/
#  http://www.benkoknehtl.si/ info@benkoknehtl.si
# AR | ORTHODONTICS https://www.instagram.com/perio.colmex/
#  http://dra-adriana-rojas-ramirez96.webnode.do// 4773390534@dra.adrianarojasr
# دندانپزشکی دکتر روشن طلب https://www.instagram.com/perio.colmex/
#  http://www.dr-roshantalab.com/ info@dr-roshantalab.com
# Refine Dentistry https://www.instagram.com/perio.colmex/
#  http://www.refinedentistry.com/ contact@refinedentistry.com
# O'DENT Clinica Dental https://www.instagram.com/perio.colmex/
#  http://www.odentclinicadental.com/ wixofday@wix.com
# El Dentalista https://www.instagram.com/perio.colmex/
#  http://www.eldentalista.com/ pacientesMorethedentalist.odontologia@gmail.com9435378
# Dr. Hansen Liang https://www.instagram.com/perio.colmex/
#  https://app.smilevirtual.com/Dr-Hansen-Liang/sign-up hello@smilevirtual.com
# Valencia Dental Center https://www.instagram.com/perio.colmex/
#  http://www.valenciadentalcenter.com/ 643-6424Emailhello@valenciadentalcenter.com
